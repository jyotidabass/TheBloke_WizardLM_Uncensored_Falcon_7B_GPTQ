# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/TheBloke_WizardLM_Uncensored_Falcon_7B_GPTQ/blob/main/TheBloke_WizardLM_Uncensored_Falcon_7B_GPTQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Dependencies and Import Modules
#
# We must build AutoGPTQ from source.

# %%
# !pip install transformers accelerate einops sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 31.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 33.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 60.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.7 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/PanQiWei/AutoGPTQ
# !pip install ./AutoGPTQ/
# Out:
# Cloning into 'AutoGPTQ'...
# remote: Enumerating objects: 3386, done.
# remote: Counting objects: 100% (541/541), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 3386 (delta 450), reused 438 (delta 418), pack-reused 2845
# Receiving objects: 100% (3386/3386), 7.67 MiB | 9.52 MiB/s, done.
# Resolving deltas: 100% (2243/2243), done.
# Processing ./AutoGPTQ
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.7 MB/s eta 0:00:00
# ...
#   error: subprocess-exited-with-error
#
# ...

# %%
import torch
# !pip install auto_gptq
from transformers import AutoTokenizer
from auto_gptq import AutoGPTQForCausalLM
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.7 MB/s eta 0:00:00
# ...
#   Using cached datasets-2.14.5-py3-none-any.whl (519 kB)
# ...
#   Using cached rouge-1.0.1-py3-none-any.whl (13 kB)
# ...
#   Using cached peft-0.5.0-py3-none-any.whl (85 kB)
# ...
#   Using cached dill-0.3.7-py3-none-any.whl (115 kB)
# ...
#   Using cached xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# ...
#   Using cached multiprocess-0.70.15-py310-none-any.whl (134 kB)
# ...

# %% [markdown]
# # Load the Model and Tokenizer
#
# This may take a while. It also requires around 3.5GB of RAM and 7.5GB of GPU. It will use 28 GB of disk space.

# %%
model_path = "TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=False)

# %%
model = AutoGPTQForCausalLM.from_quantized(model_path, device="cuda:0", use_triton=False, use_safetensors=True, torch_dtype=torch.float32, trust_remote_code=True)
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ:
# - configuration_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# A new version of the following files was downloaded from https://huggingface.co/TheBloke/WizardLM-Uncensored-Falcon-7B-GPTQ:
# - modelling_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:auto_gptq.modeling._base:can't get model's sequence length from model config, will set to 4096.
# WARNING:auto_gptq.modeling._base:RWGPTQForCausalLM hasn't fused attention module yet, will skip inject fused attention.
# WARNING:auto_gptq.modeling._base:RWGPTQForCausalLM hasn't fused mlp module yet, will skip inject fused mlp.

# %% [markdown]
# # Your Prompt
#
# You only need to change the prompt below.

# %%
prompt = "Describe a painting of a falcon hunting a llama in a very detailed way." #@param
prompt_template = f"### Instruction: {prompt}\n### Response:"

# %% [markdown]
# This will generate the output:

# %%
tokens = tokenizer(prompt_template, return_tensors="pt").input_ids.to("cuda:0")
output = model.generate(input_ids=tokens, max_new_tokens=256, do_sample=True, temperature=0.8)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
# Print the generated text
print(tokenizer.decode(output[0]))
# Out:
# ### Instruction: Describe a painting of a falcon hunting a llama in a very detailed way.
# ### Response:The painting depicts a breathtaking scene of a falcon hunting a llama in a rugged, rocky mountain landscape. The falcon, a magnificent bird of prey, is perched on a rocky outcropping, surveying the landscape below. The llama, a smaller creature compared to the falcon, is grazing peacefully on the grasslands, unaware of the danger that lies ahead.
# The falcon's piercing gaze is fixed on its prey, a small rodent scurrying through the grass. The falcon takes a deep breath, spreads its wings, and launches itself into the air. It's a magnificent sight to behold as the falcon descends, talons outstretched, towards its unsuspecting prey.
# ...
